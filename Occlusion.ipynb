# %%
from scipy.ndimage import zoom
import torch
import numpy as np

# %%
def resample_to_target_shape(data, target_shape):
    """
    Resample data to match the target shape
    """
    # Calculate zoom factors
    factors = (target_shape[0] / data.shape[0],
               target_shape[1] / data.shape[1],
               target_shape[2] / data.shape[2])

    # Resample using order=1 (linear interpolation) for continuous data
    resampled_data = zoom(data, factors, order=1)

    return resampled_data

# %%
def perform_region_occlusion_analysis(test_loader, model, device, atlas_data, region_labels, region_mapping, img_shape):
    """
    Perform occlusion analysis based on brain regions defined in the atlas
    """
    model.eval()

    print(f"Target image shape for resampling: {img_shape}")

    # Check if the atlas needs resampling
    if atlas_data.shape != img_shape:
        print(f"Resampling atlas from {atlas_data.shape} to {img_shape}")
        resampled_atlas = resample_to_target_shape(atlas_data, img_shape)
    else:
        print("Atlas already matches target shape, no resampling needed")
        resampled_atlas = atlas_data

    print(f"Resampled atlas shape: {resampled_atlas.shape}")

    # Initialize results dictionary to store effect per region
    region_occlusion_effects = {region: 0 for region in region_labels}
    region_sample_counts = {region: 0 for region in region_labels}

    print('======= Starting Region-Based Occlusion Analysis =============')

    sample_count = 0

    with torch.no_grad():
        for _, (input_img, ids, target, male) in enumerate(test_loader):
            # Print input_img shape for debugging
            print(f"Input image shape: {input_img.shape}")

            # Debugging: Print detailed shape information
            print(f"Input data type: {input_img.dtype}")

            # Get original prediction
            input_img = input_img.to(device).type(torch.FloatTensor)

            # Handle gender information if needed by model
            # if opt.model == 'ScaleDense':
            #     male_onehot = torch.unsqueeze(male, 1)
            #     male_onehot = torch.zeros(male_onehot.shape[0], 2).scatter_(1, male_onehot, 1)
            #     male_onehot = male_onehot.type(torch.FloatTensor).to(device)
            #     original_output = model(input_img, male_onehot)
            # else:
            #     original_output = model(input_img)

            original_output = model(input_img)

            # original_output = original_output.cpu().numpy()
            original_output = original_output[0].numpy()

            # Process each region one by one
            for region in region_labels:
                # Free up memory
                torch.cuda.empty_cache()

                # Create mask for this region
                region_mask = (resampled_atlas == region)

                # Skip if region is not present in the resampled atlas
                if not np.any(region_mask):
                    continue

                # Clone the original input
                masked_input = input_img.clone()

                # Move input to CPU for masking
                # cpu_input = masked_input.cpu().numpy()

                cpu_input = masked_input.numpy()

                # Create a zero array with the same shape
                zeroed_array = np.zeros_like(cpu_input)

                # Create a mask array by broadcasting the region mask
                # This safely handles all dimension arrangements
                mask_array = np.ones_like(cpu_input)

                # Apply the region mask - this is the key change
                # We're assuming the last 3 dimensions of cpu_input correspond to the 3D volume
                for i in range(cpu_input.shape[0]):  # batch dimension
                    # Create a view that can be applied to the 3D volume regardless of channel arrangement
                    mask_view = np.broadcast_to(~region_mask, cpu_input[i].shape)
                    cpu_input[i] = cpu_input[i] * mask_view

                # Move back to GPU
                masked_input = torch.from_numpy(cpu_input).to(device)

                # Get prediction for masked input
                # if opt.model == 'ScaleDense':
                #     masked_output = model(masked_input, male_onehot)
                # else:
                #     masked_output = model(masked_input)

                masked_output = model(masked_input)

                # masked_output = masked_output.cpu().numpy()
                masked_output = masked_output[0].numpy()
                print('region:- ',region_mapping[region])
                print('original_output:- ',original_output)
                print('masked_output:- ',masked_output)

                # Calculate effect for this region (difference from original)
                effect = abs(masked_output - original_output)

                # Accumulate effect for this region
                region_occlusion_effects[region] += effect.item()
                region_sample_counts[region] += 1

                # Clean up
                del masked_input, cpu_input
                if 'masked_output' in locals():
                    del masked_output
                torch.cuda.empty_cache()

            sample_count += 1
            print(f"Processed sample {sample_count}/{len(test_loader)}: {ids[0]}")

    # Average effects across samples
    for region in region_labels:
        if region_sample_counts[region] > 0:
            region_occlusion_effects[region] /= region_sample_counts[region]

    # Convert results to a structured array
    result_array = np.array([region_occlusion_effects[region] for region in region_labels])

    return result_array

# %%
import os
from Models.MultiViewViT import MultiViewViT
from load_data import IMG_Folder
import torch.nn as nn
import nibabel as nib
from nilearn import datasets

# %%
def weights_init(w):
    classname = w.__class__.__name__
    if classname.find('Conv') != -1:
        if hasattr(w, 'weight'):
            # nn.init.kaiming_normal_(w.weight, mode='fan_out', nonlinearity='relu')
            nn.init.kaiming_normal_(w.weight, mode='fan_in', nonlinearity='leaky_relu')
        if hasattr(w, 'bias') and w.bias is not None:
                nn.init.constant_(w.bias, 0)
    if classname.find('Linear') != -1:
        if hasattr(w, 'weight'):
            torch.nn.init.xavier_normal_(w.weight)
        if hasattr(w, 'bias') and w.bias is not None:
            nn.init.constant_(w.bias, 0)
    if classname.find('BatchNorm') != -1:
        if hasattr(w, 'weight') and w.weight is not None:
            nn.init.constant_(w.weight, 1)
        if hasattr(w, 'bias') and w.bias is not None:
            nn.init.constant_(w.bias, 0)

# %%
# Load model
model = MultiViewViT(
    image_sizes=[(91, 109), (91, 91), (109, 91)],
    patch_sizes=[(7, 7), (7, 7), (7, 7)],
    num_channals=[91, 109, 91],
    vit_args={
        'emb_dim': 768, 'mlp_dim': 3072, 'num_heads': 12,
        'num_layers': 12, 'num_classes': 1,
        'dropout_rate': 0.1, 'attn_dropout_rate': 0.0
    },
    mlp_dims=[3, 128, 256, 512, 1024, 512, 256, 128, 1]
)
model.apply(weights_init)
model = model.to("cpu")

# Load checkpoint
CheckpointPath = r'C:\Users\Rishabh\training_output_metricsMulti_VIT_best_model.pth.tar'
checkpoint = torch.load(CheckpointPath, map_location="cpu")
state_dict = checkpoint["state_dict"]
new_state_dict = {k.replace("module.", ""): v for k, v in state_dict.items()}
model.load_state_dict(new_state_dict)
# Out:
# <All keys matched successfully>

# %%
CheckpointPath = r'C:\Users\Rishabh\trainingMulti_VIT_best_model.pth.tar'
CSVPath = r'C:\Users\Rishabh\Documents\TransBTS\IXI.xlsx'
# DataFolder = r'C:\Users\Rishabh\Documents\TrimeseData'
DataFolder = r"C:\Users\Rishabh\TrimeesePreprocessedData"
test_data = IMG_Folder(CSVPath, DataFolder)
device = "cpu"

# %%
valid_loader = torch.utils.data.DataLoader(test_data
                                         ,batch_size=1
                                         ,num_workers=0
                                         ,pin_memory=True
                                         ,drop_last=True
                                         )

# %%
# ======== Load AAL atlas ======== #
aal_atlas = datasets.fetch_atlas_aal()
atlas_filename = aal_atlas.maps
atlas_nii = nib.load(atlas_filename)
atlas_data = atlas_nii.get_fdata()
region_labels = np.unique(atlas_data)[1:]  # Exclude 0 (background)
region_mapping = {code: label for code, label in zip(region_labels, aal_atlas.labels)}

print(f"Number of regions in atlas: {len(region_labels)}")
print(f"Atlas shape: {atlas_data.shape}")
# Out:
# C:\Users\Rishabh\AppData\Local\Temp\ipykernel_396\3018833866.py:2: DeprecationWarning: Starting in version 0.13, the default fetched mask will beAAL 3v2 instead.
#   aal_atlas = datasets.fetch_atlas_aal()
# [fetch_atlas_aal] Dataset found in C:\Users\Rishabh\nilearn_data\aal_SPM12
# Number of regions in atlas: 116
# Atlas shape: (91, 109, 91)

# %%
atlas_data.shape
# Out:
# (91, 109, 91)

# %%
len(np.unique(atlas_data))
# Out:
# 117

# %%
model.eval()
# Out:
# MultiViewViT(
#   (vit_1): VisionTransformer(
#     (embedding): Conv2d(91, 768, kernel_size=(7, 7), stride=(7, 7))
#     (transformer): Encoder(
#       (pos_embedding): PositionEmbs(
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder_layers): ModuleList(
#         (0-11): 12 x EncoderBlock(
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): SelfAttention(
#             (query): LinearGeneral()
#             (key): LinearGeneral()
#             (value): LinearGeneral()
#             (out): LinearGeneral()
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): MlpBlock(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (act): GELU(approximate='none')
#             (dropout1): Dropout(p=0.1, inplace=False)
#             (dropout2): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     )
#     (classifier): Linear(in_features=768, out_features=1, bias=True)
#   )
#   (vit_2): VisionTransformer(
#     (embedding): Conv2d(109, 768, kernel_size=(7, 7), stride=(7, 7))
#     (transformer): Encoder(
#       (pos_embedding): PositionEmbs(
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder_layers): ModuleList(
#         (0-11): 12 x EncoderBlock(
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): SelfAttention(
#             (query): LinearGeneral()
#             (key): LinearGeneral()
#             (value): LinearGeneral()
#             (out): LinearGeneral()
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): MlpBlock(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (act): GELU(approximate='none')
#             (dropout1): Dropout(p=0.1, inplace=False)
#             (dropout2): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     )
#     (classifier): Linear(in_features=768, out_features=1, bias=True)
#   )
#   (vit_3): VisionTransformer(
#     (embedding): Conv2d(91, 768, kernel_size=(7, 7), stride=(7, 7))
#     (transformer): Encoder(
#       (pos_embedding): PositionEmbs(
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder_layers): ModuleList(
#         (0-11): 12 x EncoderBlock(
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): SelfAttention(
#             (query): LinearGeneral()
#             (key): LinearGeneral()
#             (value): LinearGeneral()
#             (out): LinearGeneral()
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): MlpBlock(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (act): GELU(approximate='none')
#             (dropout1): Dropout(p=0.1, inplace=False)
#             (dropout2): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     )
#     (classifier): Linear(in_features=768, out_features=1, bias=True)
#   )
#   (mlp): Sequential(
#     (0): Linear(in_features=3, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=512, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=512, out_features=1024, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=1024, out_features=512, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=512, out_features=256, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=256, out_features=128, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
# Get sample image to determine exact shape
for sample_data in valid_loader:
    sample_img = sample_data[0]
    img_shape = (sample_img.shape[1], sample_img.shape[2], sample_img.shape[3])
    print(f"Detected image shape: {img_shape}")
    break
# Out:
# Detected image shape: (91, 109, 91)

# %%
# ======== perform region-based occlusion analysis ======== #
region_occlusion_results = perform_region_occlusion_analysis(
    test_loader=valid_loader,
    model=model,
    device="cpu",
    atlas_data=atlas_data,
    region_labels=region_labels,
    region_mapping=region_mapping,
    img_shape=img_shape
)
# Out:
# Target image shape for resampling: (91, 109, 91)
# Atlas already matches target shape, no resampling needed
# Resampled atlas shape: (91, 109, 91)
# ======= Starting Region-Based Occlusion Analysis =============
# Input image shape: torch.Size([1, 91, 109, 91])
# Input data type: torch.float32
# region:-  Background
# original_output:-  [[30.379274]]
# masked_output:-  [[31.153767]]
# region:-  Precentral_L
# original_output:-  [[30.379274]]
# masked_output:-  [[32.800705]]
# region:-  Precentral_R
# original_output:-  [[30.379274]]
# masked_output:-  [[29.600851]]
# region:-  Frontal_Sup_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.611794]]
# region:-  Frontal_Sup_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.386362]]
# region:-  Frontal_Sup_Orb_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.410652]]
# region:-  Frontal_Sup_Orb_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.791653]]
# region:-  Frontal_Mid_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.444912]]
# region:-  Frontal_Mid_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.397343]]
# region:-  Frontal_Mid_Orb_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.361296]]
# region:-  Frontal_Mid_Orb_R
# original_output:-  [[30.379274]]
# masked_output:-  [[32.12658]]
# region:-  Frontal_Inf_Oper_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.354605]]
# region:-  Frontal_Inf_Oper_R
# original_output:-  [[30.379274]]
# masked_output:-  [[31.27581]]
# region:-  Frontal_Inf_Tri_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.357967]]
# region:-  Frontal_Inf_Tri_R
# original_output:-  [[30.379274]]
# masked_output:-  [[31.34544]]
# region:-  Frontal_Inf_Orb_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.35093]]
# region:-  Frontal_Inf_Orb_R
# original_output:-  [[30.379274]]
# masked_output:-  [[31.77163]]
# region:-  Rolandic_Oper_L
# original_output:-  [[30.379274]]
# masked_output:-  [[28.35494]]
# region:-  Rolandic_Oper_R
# original_output:-  [[30.379274]]
# masked_output:-  [[29.996809]]
# region:-  Supp_Motor_Area_L
# original_output:-  [[30.379274]]
# masked_output:-  [[29.99841]]
# region:-  Supp_Motor_Area_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.41684]]
# region:-  Olfactory_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.361238]]
# region:-  Olfactory_R
# original_output:-  [[30.379274]]
# masked_output:-  [[29.27955]]
# region:-  Frontal_Sup_Medial_L
# original_output:-  [[30.379274]]
# masked_output:-  [[32.18802]]
# region:-  Frontal_Sup_Medial_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.272366]]
# region:-  Frontal_Med_Orb_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.303066]]
# region:-  Frontal_Med_Orb_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.440897]]
# region:-  Rectus_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.359814]]
# region:-  Rectus_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.43477]]
# region:-  Insula_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.365034]]
# region:-  Insula_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.407598]]
# region:-  Cingulum_Ant_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.136454]]
# region:-  Cingulum_Ant_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.01916]]
# region:-  Cingulum_Mid_L
# original_output:-  [[30.379274]]
# masked_output:-  [[29.025639]]
# region:-  Cingulum_Mid_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.37502]]
# region:-  Cingulum_Post_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.358625]]
# region:-  Cingulum_Post_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.34841]]
# region:-  Hippocampus_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.592178]]
# region:-  Hippocampus_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.473293]]
# region:-  ParaHippocampal_L
# original_output:-  [[30.379274]]
# masked_output:-  [[29.554592]]
# region:-  ParaHippocampal_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.33661]]
# region:-  Amygdala_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.38215]]
# region:-  Amygdala_R
# original_output:-  [[30.379274]]
# masked_output:-  [[29.53614]]
# region:-  Calcarine_L
# original_output:-  [[30.379274]]
# masked_output:-  [[29.36417]]
# region:-  Calcarine_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.182]]
# region:-  Cuneus_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.601368]]
# region:-  Cuneus_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.182674]]
# region:-  Lingual_L
# original_output:-  [[30.379274]]
# masked_output:-  [[29.521936]]
# region:-  Lingual_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.393057]]
# region:-  Occipital_Sup_L
# original_output:-  [[30.379274]]
# masked_output:-  [[29.518475]]
# region:-  Occipital_Sup_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.619297]]
# region:-  Occipital_Mid_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.38525]]
# region:-  Occipital_Mid_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.373222]]
# region:-  Occipital_Inf_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.380419]]
# region:-  Occipital_Inf_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.315336]]
# region:-  Fusiform_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.583958]]
# region:-  Fusiform_R
# original_output:-  [[30.379274]]
# masked_output:-  [[28.69529]]
# region:-  Postcentral_L
# original_output:-  [[30.379274]]
# masked_output:-  [[26.168919]]
# region:-  Postcentral_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.345709]]
# region:-  Parietal_Sup_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.19721]]
# region:-  Parietal_Sup_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.375935]]
# region:-  Parietal_Inf_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.04516]]
# region:-  Parietal_Inf_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.403141]]
# region:-  SupraMarginal_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.895105]]
# region:-  SupraMarginal_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.373684]]
# region:-  Angular_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.357618]]
# region:-  Angular_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.868866]]
# region:-  Precuneus_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.287235]]
# region:-  Precuneus_R
# original_output:-  [[30.379274]]
# masked_output:-  [[29.36279]]
# region:-  Paracentral_Lobule_L
# original_output:-  [[30.379274]]
# masked_output:-  [[31.532831]]
# region:-  Paracentral_Lobule_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.70073]]
# region:-  Caudate_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.496922]]
# region:-  Caudate_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.21834]]
# region:-  Putamen_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.37872]]
# region:-  Putamen_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.148035]]
# region:-  Pallidum_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.470371]]
# region:-  Pallidum_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.30707]]
# region:-  Thalamus_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.16685]]
# region:-  Thalamus_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.369745]]
# region:-  Heschl_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.286213]]
# region:-  Heschl_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.242401]]
# region:-  Temporal_Sup_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.172268]]
# region:-  Temporal_Sup_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.45441]]
# region:-  Temporal_Pole_Sup_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.237514]]
# region:-  Temporal_Pole_Sup_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.255383]]
# region:-  Temporal_Mid_L
# original_output:-  [[30.379274]]
# masked_output:-  [[29.77338]]
# region:-  Temporal_Mid_R
# original_output:-  [[30.379274]]
# masked_output:-  [[31.761574]]
# region:-  Temporal_Pole_Mid_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.337404]]
# region:-  Temporal_Pole_Mid_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.452896]]
# region:-  Temporal_Inf_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.42895]]
# region:-  Temporal_Inf_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.513283]]
# region:-  Cerebelum_Crus1_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.403084]]
# region:-  Cerebelum_Crus1_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.41101]]
# region:-  Cerebelum_Crus2_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.357664]]
# region:-  Cerebelum_Crus2_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.337294]]
# region:-  Cerebelum_3_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.261477]]
# region:-  Cerebelum_3_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.273705]]
# region:-  Cerebelum_4_5_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.267498]]
# region:-  Cerebelum_4_5_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.43148]]
# region:-  Cerebelum_6_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.419231]]
# region:-  Cerebelum_6_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.37474]]
# region:-  Cerebelum_7b_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.404762]]
# region:-  Cerebelum_7b_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.43302]]
# region:-  Cerebelum_8_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.495974]]
# region:-  Cerebelum_8_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.418823]]
# region:-  Cerebelum_9_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.387026]]
# region:-  Cerebelum_9_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.388256]]
# region:-  Cerebelum_10_L
# original_output:-  [[30.379274]]
# masked_output:-  [[30.271805]]
# region:-  Cerebelum_10_R
# original_output:-  [[30.379274]]
# masked_output:-  [[30.3776]]
# region:-  Vermis_1_2
# original_output:-  [[30.379274]]
# masked_output:-  [[30.415882]]
# region:-  Vermis_3
# original_output:-  [[30.379274]]
# masked_output:-  [[30.417007]]
# region:-  Vermis_4_5
# original_output:-  [[30.379274]]
# masked_output:-  [[30.373522]]
# region:-  Vermis_6
# original_output:-  [[30.379274]]
# masked_output:-  [[30.380207]]
# region:-  Vermis_7
# original_output:-  [[30.379274]]
# masked_output:-  [[30.37876]]
# region:-  Vermis_8
# original_output:-  [[30.379274]]
# masked_output:-  [[30.37301]]
# region:-  Vermis_9
# original_output:-  [[30.379274]]
# masked_output:-  [[30.427254]]
# Processed sample 1/39: 662
# Input image shape: torch.Size([1, 91, 109, 91])
# Input data type: torch.float32
# region:-  Background
# original_output:-  [[36.60065]]
# masked_output:-  [[36.312477]]
# region:-  Precentral_L
# original_output:-  [[36.60065]]
# masked_output:-  [[36.898453]]
# region:-  Precentral_R
# original_output:-  [[36.60065]]
# masked_output:-  [[31.493893]]
# region:-  Frontal_Sup_L
# original_output:-  [[36.60065]]
# masked_output:-  [[24.481813]]
# region:-  Frontal_Sup_R
# original_output:-  [[36.60065]]
# masked_output:-  [[37.882298]]
# region:-  Frontal_Sup_Orb_L
# original_output:-  [[36.60065]]
# masked_output:-  [[36.14052]]
# region:-  Frontal_Sup_Orb_R
# original_output:-  [[36.60065]]
# masked_output:-  [[37.070026]]
# region:-  Frontal_Mid_L
# original_output:-  [[36.60065]]
# masked_output:-  [[36.55951]]
# region:-  Frontal_Mid_R
# original_output:-  [[36.60065]]
# masked_output:-  [[36.56493]]
# region:-  Frontal_Mid_Orb_L
# original_output:-  [[36.60065]]
# masked_output:-  [[36.44625]]
# region:-  Frontal_Mid_Orb_R
# original_output:-  [[36.60065]]
# masked_output:-  [[36.584938]]
# region:-  Frontal_Inf_Oper_L
# original_output:-  [[36.60065]]
# masked_output:-  [[31.033964]]
# region:-  Frontal_Inf_Oper_R
# original_output:-  [[36.60065]]
# masked_output:-  [[36.594604]]
# region:-  Frontal_Inf_Tri_L
# original_output:-  [[36.60065]]
# masked_output:-  [[36.614784]]
# region:-  Frontal_Inf_Tri_R
# original_output:-  [[36.60065]]
# masked_output:-  [[37.055737]]
# region:-  Frontal_Inf_Orb_L
# original_output:-  [[36.60065]]
# masked_output:-  [[37.66361]]
# region:-  Frontal_Inf_Orb_R
# original_output:-  [[36.60065]]
# masked_output:-  [[36.61412]]
# region:-  Rolandic_Oper_L
# original_output:-  [[36.60065]]
# masked_output:-  [[36.437233]]
# region:-  Rolandic_Oper_R
# original_output:-  [[36.60065]]
# masked_output:-  [[49.274014]]
# region:-  Supp_Motor_Area_L
# original_output:-  [[36.60065]]
# masked_output:-  [[49.754597]]
# region:-  Supp_Motor_Area_R
# original_output:-  [[36.60065]]
# masked_output:-  [[35.955814]]
# region:-  Olfactory_L
# original_output:-  [[36.60065]]
# masked_output:-  [[36.951027]]
# region:-  Olfactory_R
# original_output:-  [[36.60065]]
# masked_output:-  [[34.568516]]
# region:-  Frontal_Sup_Medial_L
# original_output:-  [[36.60065]]
# masked_output:-  [[34.09018]]
# region:-  Frontal_Sup_Medial_R
# original_output:-  [[36.60065]]
# masked_output:-  [[36.59911]]
# region:-  Frontal_Med_Orb_L
# original_output:-  [[36.60065]]
# masked_output:-  [[35.188824]]
# region:-  Frontal_Med_Orb_R
# original_output:-  [[36.60065]]
# masked_output:-  [[34.40763]]
# region:-  Rectus_L
# original_output:-  [[36.60065]]
# masked_output:-  [[31.21899]]
# region:-  Rectus_R
# original_output:-  [[36.60065]]
# masked_output:-  [[26.055922]]
# region:-  Insula_L
# original_output:-  [[36.60065]]
# masked_output:-  [[36.58883]]
# region:-  Insula_R
# original_output:-  [[36.60065]]
# masked_output:-  [[30.77258]]
# region:-  Cingulum_Ant_L
# original_output:-  [[36.60065]]
# masked_output:-  [[35.08023]]
# region:-  Cingulum_Ant_R
# original_output:-  [[36.60065]]
# masked_output:-  [[45.212788]]
# region:-  Cingulum_Mid_L
# original_output:-  [[36.60065]]
# masked_output:-  [[41.863895]]
# region:-  Cingulum_Mid_R
# original_output:-  [[36.60065]]
# masked_output:-  [[36.62914]]
# region:-  Cingulum_Post_L
# original_output:-  [[36.60065]]
# masked_output:-  [[36.734875]]
# region:-  Cingulum_Post_R
# original_output:-  [[36.60065]]
# masked_output:-  [[36.66516]]
# region:-  Hippocampus_L
# original_output:-  [[36.60065]]
# masked_output:-  [[35.048065]]
# region:-  Hippocampus_R
# original_output:-  [[36.60065]]
# masked_output:-  [[36.834026]]
# region:-  ParaHippocampal_L
# original_output:-  [[36.60065]]
# masked_output:-  [[56.90453]]
# region:-  ParaHippocampal_R
# original_output:-  [[36.60065]]
# masked_output:-  [[36.59887]]
# region:-  Amygdala_L
# original_output:-  [[36.60065]]
# masked_output:-  [[36.00054]]
# region:-  Amygdala_R
# original_output:-  [[36.60065]]
# masked_output:-  [[39.297176]]
# region:-  Calcarine_L
# original_output:-  [[36.60065]]
# masked_output:-  [[51.896965]]
# region:-  Calcarine_R
# original_output:-  [[36.60065]]
# masked_output:-  [[33.457035]]
# region:-  Cuneus_L
# original_output:-  [[36.60065]]
# masked_output:-  [[48.539265]]
# region:-  Cuneus_R
# original_output:-  [[36.60065]]
# masked_output:-  [[39.088528]]
# region:-  Lingual_L
# original_output:-  [[36.60065]]
# masked_output:-  [[49.462875]]
# region:-  Lingual_R
# original_output:-  [[36.60065]]
# masked_output:-  [[37.151085]]
# region:-  Occipital_Sup_L
# original_output:-  [[36.60065]]
# masked_output:-  [[46.836094]]
# region:-  Occipital_Sup_R
# original_output:-  [[36.60065]]
# masked_output:-  [[39.302563]]
# region:-  Occipital_Mid_L
# original_output:-  [[36.60065]]
# masked_output:-  [[36.597565]]
# region:-  Occipital_Mid_R
# original_output:-  [[36.60065]]
# masked_output:-  [[36.982094]]
# region:-  Occipital_Inf_L
# original_output:-  [[36.60065]]
# masked_output:-  [[36.59033]]
# region:-  Occipital_Inf_R
# original_output:-  [[36.60065]]
# masked_output:-  [[36.790974]]
# region:-  Fusiform_L
# original_output:-  [[36.60065]]
# masked_output:-  [[34.94999]]
# region:-  Fusiform_R
# original_output:-  [[36.60065]]
# masked_output:-  [[36.778492]]
# region:-  Postcentral_L
# original_output:-  [[36.60065]]
# masked_output:-  [[37.461033]]
# region:-  Postcentral_R
# original_output:-  [[36.60065]]
# masked_output:-  [[36.711254]]
# region:-  Parietal_Sup_L
# original_output:-  [[36.60065]]
# masked_output:-  [[32.11335]]
# region:-  Parietal_Sup_R
# original_output:-  [[36.60065]]
# masked_output:-  [[36.64071]]
# region:-  Parietal_Inf_L
# original_output:-  [[36.60065]]
# masked_output:-  [[29.323433]]
# region:-  Parietal_Inf_R
# original_output:-  [[36.60065]]
# masked_output:-  [[28.487844]]
# region:-  SupraMarginal_L
# original_output:-  [[36.60065]]
# masked_output:-  [[30.660404]]
# region:-  SupraMarginal_R
# original_output:-  [[36.60065]]
# masked_output:-  [[36.619026]]
# region:-  Angular_L
# original_output:-  [[36.60065]]
# masked_output:-  [[36.594692]]
# region:-  Angular_R
# original_output:-  [[36.60065]]
# masked_output:-  [[35.230316]]
# region:-  Precuneus_L
# original_output:-  [[36.60065]]
# masked_output:-  [[28.66565]]
# region:-  Precuneus_R
# original_output:-  [[36.60065]]
# masked_output:-  [[46.5641]]
# region:-  Paracentral_Lobule_L
# original_output:-  [[36.60065]]
# masked_output:-  [[36.651146]]
# region:-  Paracentral_Lobule_R
# original_output:-  [[36.60065]]
# masked_output:-  [[35.84837]]
# region:-  Caudate_L
# original_output:-  [[36.60065]]
# masked_output:-  [[37.488]]
# region:-  Caudate_R
# original_output:-  [[36.60065]]
# masked_output:-  [[35.046085]]
# region:-  Putamen_L
# original_output:-  [[36.60065]]
# masked_output:-  [[36.813717]]
# region:-  Putamen_R
# original_output:-  [[36.60065]]
# masked_output:-  [[36.615814]]
# region:-  Pallidum_L
# original_output:-  [[36.60065]]
# masked_output:-  [[35.470257]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 # ======== perform region-based occlusion analysis ======== #
# ----> 2 region_occlusion_results = perform_region_occlusion_analysis(
#       3     test_loader=valid_loader,
#       4     model=model,
#       5     device="cpu",
#       6     atlas_data=atlas_data,
#       7     region_labels=region_labels,
#       8     region_mapping=region_mapping,
#       9     img_shape=img_shape
#      10 )
#
# Cell In[3], line 95, in perform_region_occlusion_analysis(test_loader, model, device, atlas_data, region_labels, region_mapping, img_shape)
#      87 masked_input = torch.from_numpy(cpu_input).to(device)
#      89 # Get prediction for masked input
#      90 # if opt.model == 'ScaleDense':
#      91 #     masked_output = model(masked_input, male_onehot)
#      92 # else:
#      93 #     masked_output = model(masked_input)
# ---> 95 masked_output = model(masked_input)
#      97 # masked_output = masked_output.cpu().numpy()
#      98 masked_output = masked_output[0].numpy()
#
# File ~\anaconda3\envs\Triamese-ViT\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\Triamese-ViT\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~\Documents\Triamese-ViT\Models\MultiViewViT.py:53, in MultiViewViT.forward(self, x, return_attention_weights)
#      50 combined_out = torch.cat([out1, out2, out3], dim=1)
#      52 # Pass through MLP
# ---> 53 prediction = self.mlp(combined_out)
#      58 if return_attention_weights:
#      59     return prediction, (attn1, attn2, attn3)
#
# File ~\anaconda3\envs\Triamese-ViT\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\Triamese-ViT\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~\anaconda3\envs\Triamese-ViT\Lib\site-packages\torch\nn\modules\container.py:240, in Sequential.forward(self, input)
#     238 def forward(self, input):
#     239     for module in self:
# --> 240         input = module(input)
#     241     return input
#
# File ~\anaconda3\envs\Triamese-ViT\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\Triamese-ViT\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~\anaconda3\envs\Triamese-ViT\Lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
def white0(image, threshold=0):
    """
    Standardize voxels with value > threshold

    Args:
        image: Input image
        threshold: Threshold value

    Returns:
        Standardized image
    """
    image = image.astype(np.float32)
    mask = (image > threshold).astype(int)

    # Vectorized implementation to avoid unnecessary memory allocation
    image_h = image * mask

    # Calculate mean and std only for relevant voxels
    non_zero_voxels = np.sum(mask)
    if non_zero_voxels > 0:
        mean = np.sum(image_h) / non_zero_voxels

        # More memory efficient way to calculate std
        std_sum = np.sum((image_h - mean * mask) ** 2)
        std = np.sqrt(std_sum / non_zero_voxels)

        if std > 0:
            normalized = mask * (image - mean) / std
            # Use in-place operations to reduce memory usage
            image = normalized + image * (1 - mask)
            return image

    # Default case
    return np.zeros_like(image, dtype=np.float32)

# %%
fileidx = 10
Files = os.listdir(DataFolder)
img_data = nib.load(os.path.join(DataFolder, Files[fileidx]))
img_data = img_data.get_fdata()
# img_data = white0(img_data)
np.unique(img_data[indx, :, :])

# %%
import matplotlib.pyplot as plt
import numpy as np

indx = 45
region_indx = 1
# maskedimage = (sample_img == region_labels[region_indx])
maskedimage = (atlas_data == 2401)
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Axial (XY plane)
axes[0].imshow(img_data[indx, :, :], cmap="gray")
axes[0].set_title("Axial")
axes[0].axis("off")

# Coronal (XZ plane)
axes[1].imshow(maskedimage[indx,:, :], cmap="gray")
axes[1].set_title("Coronal")
axes[1].axis("off")

# print(np.unique(atlas_data[indx,:, :]))
# print(np.unique(maskedimage[0,indx,:, :],))
# Sagittal (YZ plane)
print(np.unique(img_data[indx, :, :]))
print(np.unique(atlas_data[indx,:, :]))
maskedimage = np.where(maskedimage, 1, img_data)
print(np.unique(maskedimage[indx,:, :]))
axes[2].imshow(maskedimage[indx,:, :], cmap="gray")
axes[2].set_title("Sagittal")
axes[2].axis("off")
# print(np.unique(maskedimage[0,indx,:, :],))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

indx = 45
region_indx = 1
# maskedimage = (sample_img == region_labels[region_indx])
maskedimage1 = (atlas_data == 4011)
maskedimage2 = (atlas_data == 4021)
maskedimage3 = (atlas_data == 8112)
maskedimage4 = (atlas_data == 8302)
maskedimage5 = (atlas_data == 6401)
maskedimage6 = (atlas_data == 9062)
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Axial (XY plane)
axes[0].imshow(img_data[ :,indx, :], cmap="gray")
axes[0].set_title("Axial")
axes[0].axis("off")

# Coronal (XZ plane)
axes[1].imshow(atlas_data[:,indx, :], cmap="gray")
axes[1].set_title("Coronal")
axes[1].axis("off")

# print(np.unique(atlas_data[indx,:, :]))
# print(np.unique(maskedimage[0,indx,:, :],))
# Sagittal (YZ plane)
# print(np.unique(img_data[indx, :, :]))
print(np.unique(atlas_data[:,indx, :]))
new_img = np.where(maskedimage1, 1, img_data)
new_img = np.where(maskedimage2, 1, new_img)
new_img = np.where(maskedimage3, 1, new_img)
new_img = np.where(maskedimage4, 1, new_img)
new_img = np.where(maskedimage5, 1, new_img)
new_img = np.where(maskedimage6, 1, new_img)
print(np.unique(maskedimage[indx,:, :]))
axes[2].imshow(new_img[:,indx, :], cmap="gray")
axes[2].set_title("Sagittal")
axes[2].axis("off")
# print(np.unique(maskedimage[0,indx,:, :],))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

indx = 45
region_indx = 1
# maskedimage = (sample_img == region_labels[region_indx])
maskedimage1 = (atlas_data == 4011)
maskedimage2 = (atlas_data == 4021)
maskedimage3 = (atlas_data == 8112)
maskedimage4 = (atlas_data == 8302)
maskedimage5 = (atlas_data == 6401)
maskedimage6 = (atlas_data == 9062)
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Axial (XY plane)
axes[0].imshow(img_data[ :, :,indx], cmap="gray")
axes[0].set_title("Axial")
axes[0].axis("off")

# Coronal (XZ plane)
axes[1].imshow(atlas_data[:, :, indx], cmap="gray")
axes[1].set_title("Coronal")
axes[1].axis("off")

# print(np.unique(atlas_data[indx,:, :]))
# print(np.unique(maskedimage[0,indx,:, :],))
# Sagittal (YZ plane)
# print(np.unique(img_data[indx, :, :]))
print(np.unique(atlas_data[:,:, indx]))
new_img = np.where(maskedimage1, 1, img_data)
new_img = np.where(maskedimage2, 1, new_img)
new_img = np.where(maskedimage3, 1, new_img)
new_img = np.where(maskedimage4, 1, new_img)
new_img = np.where(maskedimage5, 1, new_img)
new_img = np.where(maskedimage6, 1, new_img)
print(np.unique(maskedimage[indx,:, :]))
axes[2].imshow(new_img[:, :,indx], cmap="gray")
axes[2].set_title("Sagittal")
axes[2].axis("off")
# print(np.unique(maskedimage[0,indx,:, :],))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example: fake 3D image (depth, height, width)
img = np.random.rand(64, 128, 128)

indx = 45
# Pick slice indices
slice1 = sample_img[0,:,indx,:]   # axial slice (z=30)
slice2 = atlas_data[:,indx,:]   # coronal slice (y=60)

# Plot them side by side
plt.figure(figsize=(10,5))

plt.subplot(1, 2, 1)
plt.imshow(slice1, cmap="gray")
plt.title("Axial slice")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(slice2, cmap="gray")
plt.title("Coronal slice")
plt.axis("off")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example: fake 3D image (depth, height, width)
img = np.random.rand(64, 128, 128)

indx = 45
# Pick slice indices
slice1 = sample_img[0,:,:,indx]   # axial slice (z=30)
slice2 = atlas_data[:,:,indx]   # coronal slice (y=60)

# Plot them side by side
plt.figure(figsize=(10,5))

plt.subplot(1, 2, 1)
plt.imshow(slice1, cmap="gray")
plt.title("Axial slice")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(slice2, cmap="gray")
plt.title("Coronal slice")
plt.axis("off")

plt.show()
